# %%
import pandas as pd

file_path = "data_raw/primary.csv"   # NOT ../ !!
datafile = pd.read_csv(file_path)

datafile.head()
# Out:
#   Reference Area  Time Period          Sex       Age group  \
# 0    Afghanistan         2014  All genders  Not applicable
# 1    Afghanistan         2014       Female  Not applicable
# 2    Afghanistan         2013       Female  Not applicable
# 3    Afghanistan         2013  All genders  Not applicable
# 4    Afghanistan         2012  All genders  Not applicable
#
#   Units of measurement  Observation Value
# 0               Number          6217756.0
# 1               Number          2484471.0
# 2               Number          2401135.0
# 3               Number          5986268.0
# 4               Number          5767543.0

# %%
datafile = datafile.rename(columns = {
    "Reference Area" : "Country",
    "Time " : "Year",
    "Sex" : "Gender",
    "Observation Value" : "Number "
})

datafile.head()
# Out:
#        Country  Time Period       Gender       Age group Units of measurement  \
# 0  Afghanistan         2014  All genders  Not applicable               Number
# 1  Afghanistan         2014       Female  Not applicable               Number
# 2  Afghanistan         2013       Female  Not applicable               Number
# 3  Afghanistan         2013  All genders  Not applicable               Number
# 4  Afghanistan         2012  All genders  Not applicable               Number
#
#    Number of Enrolment
# 0            6217756.0
# 1            2484471.0
# 2            2401135.0
# 3            5986268.0
# 4            5767543.0
